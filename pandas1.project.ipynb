# %% [markdown]
# project the country

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'Countries1.csv')
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
df.shape
# Out:
# (194, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
df.describe()
# Out:
#          latitude   longitude  agricultural_land   forest_area     land_area  \
# count  194.000000  194.000000       1.930000e+02  1.940000e+02  1.940000e+02
# mean    18.975601   22.027491       2.454551e+05  2.086784e+05  6.675087e+05
# std     23.876225   66.396389       6.356268e+05  7.824926e+05  1.837107e+06
# min    -41.000000 -175.000000       4.000000e+00  0.000000e+00  2.027000e+00
# 25%      4.000000   -5.000000       6.464000e+03  3.331775e+03  2.355250e+04
# 50%     16.583333   21.500000       3.872780e+04  2.528925e+04  1.203750e+05
# 75%     40.000000   50.162500       2.150000e+05  1.236735e+05  5.237000e+05
# max     65.000000  178.000000       5.285080e+06  8.153120e+06  1.637690e+07
#
#          rural_land     urban_land  central_government_debt_pct_gdp  \
# count  1.940000e+02     194.000000                       120.000000
# mean   6.563711e+05    9777.116531                        66.759366
# std    1.811169e+06   42301.458421                        71.806247
# ...

# %% [markdown]
# Q1.Which country has a highest population

# %%
df[df['population']==df['population'].max()]['country']
# Out:
# 75    India
# Name: country, dtype: object

# %% [markdown]
# Q2. What is the capital of the country highest population

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'currency', 'capital_city', 'region',
#        'continent', 'demonym', 'latitude', 'longitude', 'agricultural_land',
#        'forest_area', 'land_area', 'rural_land', 'urban_land',
#        'central_government_debt_pct_gdp', 'expense_pct_gdp', 'gdp',
#        'inflation', 'self_employed_pct', 'tax_revenue_pct_gdp',
#        'unemployment_pct', 'vulnerable_employment_pct',
#        'electricity_access_pct', 'alternative_nuclear_energy_pct',
#        'electricty_production_coal_pct',
#        'electricty_production_hydroelectric_pct',
#        'electricty_production_gas_pct', 'electricty_production_nuclear_pct',
#        'electricty_production_oil_pct', 'electricty_production_renewable_pct',
#        'energy_imports_pct', 'fossil_energy_consumption_pct',
#        'renewable_energy_consumption_pct', 'co2_emissions',
#        'methane_emissions', 'nitrous_oxide_emissions',
#        'greenhouse_other_emissions', 'urban_population_under_5m',
# ...

# %%
df[df['population'] == df['population'].max()]['capital_city']
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %% [markdown]
# Q3. Which country has the list population

# %%
df[df['population'] ==df['population'].min()]['country']
# Out:
# 179    Tuvalu
# Name: country, dtype: object

# %% [markdown]
# Q4. what is the capital of  the country with least populaion

# %%
df[df['population'] == df['population'].min()]['capital_city']
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %% [markdown]
# Q5  Give me a five country with high democratic score

# %%
df.head
# Out:
# <bound method NDFrame.head of                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %% [markdown]
# Que 6. What is the capital of country with latesst popolation

# %%
df.sort_values(by='democracy_score',ascending=False,inplace=True)

# %%
df.head()
# Out:
#          country         country_long            currency capital_city  \
# 127       Norway    Kingdom of Norway     Norwegian krone         Oslo
# 74       Iceland  Republic of Iceland       Iceland krona    Reykjavík
# 164       Sweden    Kingdom of Sweden       Swedish krona    Stockholm
# 122  New Zealand          New Zealand  New Zealand dollar   Wellington
# 46       Denmark   Kingdom of Denmark        Danish krone   Copenhagen
#
#                         region continent        demonym  latitude  longitude  \
# 127            Northern Europe    Europe      Norwegian      62.0       10.0
# 74             Northern Europe    Europe      Icelander      65.0      -18.0
# 164            Northern Europe    Europe        Swedish      62.0       15.0
# 122  Australia and New Zealand   Oceania  New Zealander     -41.0      174.0
# 46             Northern Europe    Europe         Danish      56.0       10.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %%
df['country'].head()
# Out:
# 127         Norway
# 74         Iceland
# 164         Sweden
# 122    New Zealand
# 46         Denmark
# Name: country, dtype: object

# %% [markdown]
# Que 6. How many total resion are there

# %%
df['region'].value_counts().count()
# Out:
# np.int64(22)

# %%
df
# Out:
#          country                 country_long              currency  \
# 127       Norway            Kingdom of Norway       Norwegian krone
# 74       Iceland          Republic of Iceland         Iceland krona
# 164       Sweden            Kingdom of Sweden         Swedish krona
# 122  New Zealand                  New Zealand    New Zealand dollar
# 46       Denmark           Kingdom of Denmark          Danish krone
# ..           ...                          ...                   ...
# 156  South Sudan      Republic of South Sudan  South Sudanese Pound
# 174        Tonga             Kingdom of Tonga        Tongan pa'anga
# 170  The Bahamas  Commonwealth of The Bahamas       Bahamian dollar
# 179       Tuvalu                       Tuvalu     Australian dollar
# 187      Vanuatu          Republic of Vanuatu          Vanuatu vatu
#
#     capital_city                     region continent         demonym  \
# 127         Oslo            Northern Europe    Europe       Norwegian
# ...

# %% [markdown]
# Que 7. How many  country lies in Eastern Europian Resion

# %%
df['region']
# Out:
# np.int64(22)

# %%
df['region'].value_counts()['Eastern Europe']
# Out:
# np.int64(10)

# %%
df[df['region'] == 'Eastern Europe']['country']
# Out:
# 43      Czech Republic
# 151    Slovak Republic
# 24            Bulgaria
# 136             Poland
# 73             Hungary
# 139            Romania
# 111            Moldova
# 181            Ukraine
# 14             Belarus
# 140             Russia
# Name: country, dtype: object

# %% [markdown]
# Que 8. Who is the political leader of a 2nd highest  populated  country

# %%
# nlargest means a multiple list
df[df['population'] == df['population'].nlargest(2).iloc[1]]['political_leader']
# Out:
# 34    Xi Jinping
# Name: political_leader, dtype: object

# %% [markdown]
# Que 8. how many country are there  whose political leader are un known

# %%
df[df['political_leader'].isna()]
# Out:
#                             country                        country_long  \
# 27                       Cabo Verde              Republic of Cabo Verde
# 172                     Timor-Leste  Democratic Republic of Timor-Leste
# 151                 Slovak Republic                     Slovak Republic
# 190              West Bank and Gaza                  West Bank and Gaza
# 161  St. Vincent and the Grenadines      St. Vincent and the Grenadines
# 159             St. Kitts and Nevis                 St. Kitts and Nevis
# 160                       St. Lucia                           St. Lucia
#
#                   currency capital_city              region continent  \
# 27       Cabo Verde escudo        Praia      Western Africa    Africa
# 172            U.S. dollar         Dili  South-Eastern Asia      Asia
# 151                   Euro   Bratislava      Eastern Europe    Europe
# 190     Israeli new shekel     Ramallah        Western Asia      Asia
# ...

# %%
df[df['political_leader'].isna()]['country'].count()
# Out:
# np.int64(7)

# %% [markdown]
# Que 9. How many country have republic in full name

# %%
count =0
def  counting(txt):
    global count
    if 'republic' in txt.lower():
        count+=1

    return txt
df['country_long']=df['country_long'].apply(counting)
print(count)
# Out:
# 125

# %% [markdown]
# Que 10 Which coutry in african resion in highest population

# %%
africca_df =df[df['continent'] == 'Africa']
africca_df
# Out:
#                       country                                  country_long  \
# 108                 Mauritius                         Republic of Mauritius
# 27                 Cabo Verde                        Republic of Cabo Verde
# 21                   Botswana                          Republic of Botswana
# 155              South Africa                      Republic of South Africa
# 94                    Lesotho                            Kingdom of Lesotho
# 64                      Ghana                             Republic of Ghana
# 176                   Tunisia                           Republic of Tunisia
# 118                   Namibia                           Republic of Namibia
# 146                   Senegal                           Republic of Senegal
# 17                      Benin                             Republic of Benin
# 192                    Zambia                            Republic of Zambia
# ...

# %%
africca_df[africca_df['population'] == africca_df['population'].max()]
# Out:
#      country                 country_long        currency capital_city  \
# 125  Nigeria  Federal Republic of Nigeria  Nigerian naira        Abuja
#
#              region continent   demonym  latitude  longitude  \
# 125  Western Africa    Africa  Nigerian      10.0        8.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# 125           694500.0  ...   218541212                     3.61111
#
#      rural_population  urban_population  press  democracy_score  \
# 125         101575770         116965442   2.14             4.44
#
#      democracy_type  median_age  political_leader      title
# 125   Hybrid regime        13.2  Muhammadu Buhari  President
#
# [1 rows x 64 columns]
